# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from os import listdir
import glob
from PIL import Image
import cv2
from random import randrange
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ori_images = 'dataset/train/Images'
mask_images = 'dataset/train/Masks'

# %%
def load_data(dataset_path, split=0.2):
    images = [f for f in glob.glob(ori_images + "**/*.jpg", recursive=True)]
    masks = [f for f in glob.glob(mask_images + "**/*.png", recursive=True)]

    test_size = int(len(images) * split)

    train_x, test_x = train_test_split(images, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(masks, test_size=test_size, random_state=42)

    return (train_x, train_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  
    x = cv2.resize(x, (128, 128))
    x = x/255.0
    x = x.astype(np.float32)
    return x

# %%
def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  
    x = cv2.resize(x, (128, 128))
    x = x/255.0
    x = x.astype(np.float32)                    
    x = np.expand_dims(x, axis=-1)              
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([128, 128, 3])
    y.set_shape([128, 128, 1])
    return x, y

def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
dataset_path = "dataset"
(train_x, train_y), (test_x, test_y) = load_data(dataset_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Test: {len(test_x)} - {len(test_y)}")
# Out:
# Train: 800 - 800
# Test: 200 - 200

# %%
batch = 4
train_dataset = tf_dataset(train_x, train_y, batch)
valid_dataset = tf_dataset(test_x, test_y, batch)

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    """ Bridge """
    b1 = conv_block(p4, 1024)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    """ Outputs """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    """ Model """
    model = Model(inputs, outputs)
    return model

# %%
model = build_unet((128, 128, 3))
model.compile(loss="binary_crossentropy", optimizer=Adam(), metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 128)  147584      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)   0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 1024)   4719616     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 1024)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 1024)   9438208     ['activation_8[0][0]']
#  batch_normalization_9 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 1024)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  36928       ['activation_16[0][0]']
#                                 )
#  batch_normalization_17 (BatchN  (None, 128, 128, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
model_path = 'files/final_model.h5'
callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True, monitor = 'accuracy')
    ]

# %%
batch_size = 32
num_epoch = 50

# %%
model.fit(
    train_dataset.repeat(),
    epochs=num_epoch,
    validation_data=valid_dataset.repeat(),
    steps_per_epoch=len(train_x)//batch_size,
    validation_steps=len(test_x)//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 25/25 [==============================] - ETA: 0s - loss: 0.4466 - accuracy: 0.8238
# Epoch 1: accuracy improved from -inf to 0.82384, saving model to files\final_model.h5
# 25/25 [==============================] - 122s 5s/step - loss: 0.4466 - accuracy: 0.8238 - val_loss: 374.7655 - val_accuracy: 0.3337
# Epoch 2/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.8897
# Epoch 2: accuracy improved from 0.82384 to 0.88967, saving model to files\final_model.h5
# 25/25 [==============================] - 119s 5s/step - loss: 0.3007 - accuracy: 0.8897 - val_loss: 124.4853 - val_accuracy: 0.3670
# Epoch 3/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8743
# Epoch 3: accuracy did not improve from 0.88967
# 25/25 [==============================] - 101s 4s/step - loss: 0.3092 - accuracy: 0.8743 - val_loss: 7.6078 - val_accuracy: 0.4784
# Epoch 4/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.8744
# Epoch 4: accuracy did not improve from 0.88967
# 25/25 [==============================] - 106s 4s/step - loss: 0.3165 - accuracy: 0.8744 - val_loss: 33.1089 - val_accuracy: 0.4705
# Epoch 5/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.8722
# Epoch 5: accuracy did not improve from 0.88967
# 25/25 [==============================] - 103s 4s/step - loss: 0.3277 - accuracy: 0.8722 - val_loss: 2.9988 - val_accuracy: 0.6358
# Epoch 6/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8657
# Epoch 6: accuracy did not improve from 0.88967
# 25/25 [==============================] - 97s 4s/step - loss: 0.3338 - accuracy: 0.8657 - val_loss: 2.8375 - val_accuracy: 0.6547
# Epoch 7/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3045 - accuracy: 0.8693
# Epoch 7: accuracy did not improve from 0.88967
# 25/25 [==============================] - 91s 4s/step - loss: 0.3045 - accuracy: 0.8693 - val_loss: 3.4362 - val_accuracy: 0.7119
# Epoch 8/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2671 - accuracy: 0.8949
# Epoch 8: accuracy improved from 0.88967 to 0.89485, saving model to files\final_model.h5
# 25/25 [==============================] - 95s 4s/step - loss: 0.2671 - accuracy: 0.8949 - val_loss: 2.0602 - val_accuracy: 0.7187
# Epoch 9/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.9060
# Epoch 9: accuracy improved from 0.89485 to 0.90599, saving model to files\final_model.h5
# 25/25 [==============================] - 93s 4s/step - loss: 0.2519 - accuracy: 0.9060 - val_loss: 1.2854 - val_accuracy: 0.7313
# Epoch 10/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9139
# Epoch 10: accuracy improved from 0.90599 to 0.91389, saving model to files\final_model.h5
# 25/25 [==============================] - 92s 4s/step - loss: 0.2198 - accuracy: 0.9139 - val_loss: 3.1007 - val_accuracy: 0.7004
# Epoch 11/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9182
# Epoch 11: accuracy improved from 0.91389 to 0.91823, saving model to files\final_model.h5
# 25/25 [==============================] - 90s 4s/step - loss: 0.2051 - accuracy: 0.9182 - val_loss: 0.9829 - val_accuracy: 0.7797
# Epoch 12/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.8944
# Epoch 12: accuracy did not improve from 0.91823
# 25/25 [==============================] - 88s 4s/step - loss: 0.2778 - accuracy: 0.8944 - val_loss: 0.6085 - val_accuracy: 0.8252
# Epoch 13/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2950 - accuracy: 0.8847
# Epoch 13: accuracy did not improve from 0.91823
# 25/25 [==============================] - 97s 4s/step - loss: 0.2950 - accuracy: 0.8847 - val_loss: 2.6966 - val_accuracy: 0.6450
# Epoch 14/50
# 25/25 [==============================] - ETA: 0s - loss: 0.3118 - accuracy: 0.8728
# Epoch 14: accuracy did not improve from 0.91823
# 25/25 [==============================] - 93s 4s/step - loss: 0.3118 - accuracy: 0.8728 - val_loss: 0.5400 - val_accuracy: 0.7784
# Epoch 15/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.8866
# Epoch 15: accuracy did not improve from 0.91823
# 25/25 [==============================] - 95s 4s/step - loss: 0.2733 - accuracy: 0.8866 - val_loss: 0.4138 - val_accuracy: 0.8391
# Epoch 16/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2275 - accuracy: 0.9100
# Epoch 16: accuracy did not improve from 0.91823
# 25/25 [==============================] - 91s 4s/step - loss: 0.2275 - accuracy: 0.9100 - val_loss: 0.5840 - val_accuracy: 0.8146
# Epoch 17/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9219
# Epoch 17: accuracy improved from 0.91823 to 0.92195, saving model to files\final_model.h5
# 25/25 [==============================] - 91s 4s/step - loss: 0.2167 - accuracy: 0.9219 - val_loss: 0.4224 - val_accuracy: 0.8634
# Epoch 18/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1862 - accuracy: 0.9286
# Epoch 18: accuracy improved from 0.92195 to 0.92863, saving model to files\final_model.h5
# 25/25 [==============================] - 92s 4s/step - loss: 0.1862 - accuracy: 0.9286 - val_loss: 1.0936 - val_accuracy: 0.8033
# Epoch 19/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9195
# Epoch 19: accuracy did not improve from 0.92863
# 25/25 [==============================] - 93s 4s/step - loss: 0.2058 - accuracy: 0.9195 - val_loss: 0.7188 - val_accuracy: 0.7885
# Epoch 20/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.9000
# Epoch 20: accuracy did not improve from 0.92863
# 25/25 [==============================] - 102s 4s/step - loss: 0.2602 - accuracy: 0.9000 - val_loss: 0.2810 - val_accuracy: 0.8730
# Epoch 21/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.9048
# Epoch 21: accuracy did not improve from 0.92863
# 25/25 [==============================] - 90s 4s/step - loss: 0.2543 - accuracy: 0.9048 - val_loss: 0.6533 - val_accuracy: 0.8108
# Epoch 22/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8842
# Epoch 22: accuracy did not improve from 0.92863
# 25/25 [==============================] - 95s 4s/step - loss: 0.2799 - accuracy: 0.8842 - val_loss: 0.2391 - val_accuracy: 0.9060
# Epoch 23/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.8961
# Epoch 23: accuracy did not improve from 0.92863
# 25/25 [==============================] - 92s 4s/step - loss: 0.2535 - accuracy: 0.8961 - val_loss: 0.3649 - val_accuracy: 0.8579
# Epoch 24/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9241
# Epoch 24: accuracy did not improve from 0.92863
# 25/25 [==============================] - 99s 4s/step - loss: 0.2022 - accuracy: 0.9241 - val_loss: 0.3877 - val_accuracy: 0.8756
# Epoch 25/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1950 - accuracy: 0.9286
# Epoch 25: accuracy did not improve from 0.92863
# 25/25 [==============================] - 101s 4s/step - loss: 0.1950 - accuracy: 0.9286 - val_loss: 0.3400 - val_accuracy: 0.8765
# Epoch 26/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1805 - accuracy: 0.9313
# Epoch 26: accuracy improved from 0.92863 to 0.93133, saving model to files\final_model.h5
# 25/25 [==============================] - 95s 4s/step - loss: 0.1805 - accuracy: 0.9313 - val_loss: 0.3496 - val_accuracy: 0.8884
# Epoch 27/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9261
# Epoch 27: accuracy did not improve from 0.93133
# 25/25 [==============================] - 91s 4s/step - loss: 0.1894 - accuracy: 0.9261 - val_loss: 0.4233 - val_accuracy: 0.8503
# Epoch 28/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9078
# Epoch 28: accuracy did not improve from 0.93133
# 25/25 [==============================] - 92s 4s/step - loss: 0.2347 - accuracy: 0.9078 - val_loss: 0.2464 - val_accuracy: 0.9061
# Epoch 29/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.9125
# Epoch 29: accuracy did not improve from 0.93133
# 25/25 [==============================] - 94s 4s/step - loss: 0.2177 - accuracy: 0.9125 - val_loss: 0.2135 - val_accuracy: 0.9194
# Epoch 30/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9063
# Epoch 30: accuracy did not improve from 0.93133
# 25/25 [==============================] - 96s 4s/step - loss: 0.2430 - accuracy: 0.9063 - val_loss: 0.3431 - val_accuracy: 0.9019
# Epoch 31/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2313 - accuracy: 0.9056
# Epoch 31: accuracy did not improve from 0.93133
# 25/25 [==============================] - 93s 4s/step - loss: 0.2313 - accuracy: 0.9056 - val_loss: 0.7697 - val_accuracy: 0.7775
# Epoch 32/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9252
# Epoch 32: accuracy did not improve from 0.93133
# 25/25 [==============================] - 91s 4s/step - loss: 0.1976 - accuracy: 0.9252 - val_loss: 0.6629 - val_accuracy: 0.8356
# Epoch 33/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9268
# Epoch 33: accuracy did not improve from 0.93133
# 25/25 [==============================] - 91s 4s/step - loss: 0.1933 - accuracy: 0.9268 - val_loss: 0.2635 - val_accuracy: 0.9043
# Epoch 34/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1695 - accuracy: 0.9339
# Epoch 34: accuracy improved from 0.93133 to 0.93386, saving model to files\final_model.h5
# 25/25 [==============================] - 92s 4s/step - loss: 0.1695 - accuracy: 0.9339 - val_loss: 0.2637 - val_accuracy: 0.9071
# Epoch 35/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9360
# Epoch 35: accuracy improved from 0.93386 to 0.93600, saving model to files\final_model.h5
# 25/25 [==============================] - 106s 4s/step - loss: 0.1681 - accuracy: 0.9360 - val_loss: 0.2216 - val_accuracy: 0.9192
# Epoch 36/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9092
# Epoch 36: accuracy did not improve from 0.93600
# 25/25 [==============================] - 103s 4s/step - loss: 0.2260 - accuracy: 0.9092 - val_loss: 0.2807 - val_accuracy: 0.8824
# Epoch 37/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2071 - accuracy: 0.9176
# Epoch 37: accuracy did not improve from 0.93600
# 25/25 [==============================] - 103s 4s/step - loss: 0.2071 - accuracy: 0.9176 - val_loss: 0.3285 - val_accuracy: 0.8779
# Epoch 38/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2377 - accuracy: 0.9075
# Epoch 38: accuracy did not improve from 0.93600
# 25/25 [==============================] - 95s 4s/step - loss: 0.2377 - accuracy: 0.9075 - val_loss: 0.3310 - val_accuracy: 0.8455
# Epoch 39/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9110
# Epoch 39: accuracy did not improve from 0.93600
# 25/25 [==============================] - 92s 4s/step - loss: 0.2217 - accuracy: 0.9110 - val_loss: 0.5028 - val_accuracy: 0.8454
# Epoch 40/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1831 - accuracy: 0.9305
# Epoch 40: accuracy did not improve from 0.93600
# 25/25 [==============================] - 91s 4s/step - loss: 0.1831 - accuracy: 0.9305 - val_loss: 0.3642 - val_accuracy: 0.8488
# Epoch 41/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9297
# Epoch 41: accuracy did not improve from 0.93600
# 25/25 [==============================] - 91s 4s/step - loss: 0.1876 - accuracy: 0.9297 - val_loss: 0.4019 - val_accuracy: 0.8515
# Epoch 42/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9333
# Epoch 42: accuracy did not improve from 0.93600
# 25/25 [==============================] - 91s 4s/step - loss: 0.1703 - accuracy: 0.9333 - val_loss: 0.3170 - val_accuracy: 0.8585
# Epoch 43/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9377
# Epoch 43: accuracy improved from 0.93600 to 0.93773, saving model to files\final_model.h5
# 25/25 [==============================] - 96s 4s/step - loss: 0.1606 - accuracy: 0.9377 - val_loss: 0.2216 - val_accuracy: 0.9164
# Epoch 44/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2149 - accuracy: 0.9175
# Epoch 44: accuracy did not improve from 0.93773
# 25/25 [==============================] - 96s 4s/step - loss: 0.2149 - accuracy: 0.9175 - val_loss: 0.3053 - val_accuracy: 0.8757
# Epoch 45/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9208
# Epoch 45: accuracy did not improve from 0.93773
# 25/25 [==============================] - 89s 4s/step - loss: 0.1993 - accuracy: 0.9208 - val_loss: 0.1926 - val_accuracy: 0.9223
# Epoch 46/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9172
# Epoch 46: accuracy did not improve from 0.93773
# 25/25 [==============================] - 90s 4s/step - loss: 0.2118 - accuracy: 0.9172 - val_loss: 0.2406 - val_accuracy: 0.9143
# Epoch 47/50
# 25/25 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9171
# Epoch 47: accuracy did not improve from 0.93773
# 25/25 [==============================] - 91s 4s/step - loss: 0.2020 - accuracy: 0.9171 - val_loss: 0.4255 - val_accuracy: 0.8835
# Epoch 48/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9347
# Epoch 48: accuracy did not improve from 0.93773
# 25/25 [==============================] - 93s 4s/step - loss: 0.1703 - accuracy: 0.9347 - val_loss: 0.2357 - val_accuracy: 0.8870
# Epoch 49/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9285
# Epoch 49: accuracy did not improve from 0.93773
# 25/25 [==============================] - 93s 4s/step - loss: 0.1886 - accuracy: 0.9285 - val_loss: 0.1859 - val_accuracy: 0.9282
# Epoch 50/50
# 25/25 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9348
# Epoch 50: accuracy did not improve from 0.93773
# 25/25 [==============================] - 91s 4s/step - loss: 0.1633 - accuracy: 0.9348 - val_loss: 0.2484 - val_accuracy: 0.9054

# %%
def graph():
    #Plot training & validation accuracy values
    plt.plot(model.history.history['accuracy'])
    plt.plot(model.history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(model.history.history['loss'])
    plt.plot(model.history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

graph()
